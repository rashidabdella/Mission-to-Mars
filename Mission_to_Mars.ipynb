# %%
# Import Splinter and BeautifulSoup
from splinter import Browser
from bs4 import BeautifulSoup as soup
from webdriver_manager.chrome import ChromeDriverManager

# %%
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC



from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC

# %%
pip install selenium
# Out:
# Requirement already satisfied: selenium in c:\users\rashi\anaconda3\envs\pythondata\lib\site-packages (4.3.0)
# Requirement already satisfied: trio-websocket~=0.9 in c:\users\rashi\anaconda3\envs\pythondata\lib\site-packages (from selenium) (0.9.2)
# Requirement already satisfied: urllib3[secure,socks]~=1.26 in c:\users\rashi\anaconda3\envs\pythondata\lib\site-packages (from selenium) (1.26.7)
# Requirement already satisfied: trio~=0.17 in c:\users\rashi\anaconda3\envs\pythondata\lib\site-packages (from selenium) (0.21.0)
# Requirement already satisfied: cffi>=1.14 in c:\users\rashi\anaconda3\envs\pythondata\lib\site-packages (from trio~=0.17->selenium) (1.14.6)
# Requirement already satisfied: attrs>=19.2.0 in c:\users\rashi\anaconda3\envs\pythondata\lib\site-packages (from trio~=0.17->selenium) (21.2.0)
# Requirement already satisfied: sortedcontainers in c:\users\rashi\anaconda3\envs\pythondata\lib\site-packages (from trio~=0.17->selenium) (2.4.0)
# Requirement already satisfied: outcome in c:\users\rashi\anaconda3\envs\pythondata\lib\site-packages (from trio~=0.17->selenium) (1.2.0)
# Requirement already satisfied: sniffio in c:\users\rashi\anaconda3\envs\pythondata\lib\site-packages (from trio~=0.17->selenium) (1.2.0)
# Requirement already satisfied: idna in c:\users\rashi\anaconda3\envs\pythondata\lib\site-packages (from trio~=0.17->selenium) (3.2)
# Requirement already satisfied: async-generator>=1.9 in c:\users\rashi\anaconda3\envs\pythondata\lib\site-packages (from trio~=0.17->selenium) (1.10)
# Requirement already satisfied: pycparser in c:\users\rashi\anaconda3\envs\pythondata\lib\site-packages (from cffi>=1.14->trio~=0.17->selenium) (2.20)
# Requirement already satisfied: wsproto>=0.14 in c:\users\rashi\anaconda3\envs\pythondata\lib\site-packages (from trio-websocket~=0.9->selenium) (1.1.0)
# Requirement already satisfied: PySocks!=1.5.7,<2.0,>=1.5.6 in c:\users\rashi\anaconda3\envs\pythondata\lib\site-packages (from urllib3[secure,socks]~=1.26->selenium) (1.7.1)
# Requirement already satisfied: pyOpenSSL>=0.14 in c:\users\rashi\anaconda3\envs\pythondata\lib\site-packages (from urllib3[secure,socks]~=1.26->selenium) (21.0.0)
# Requirement already satisfied: cryptography>=1.3.4 in c:\users\rashi\anaconda3\envs\pythondata\lib\site-packages (from urllib3[secure,socks]~=1.26->selenium) (3.4.8)
# Requirement already satisfied: certifi in c:\users\rashi\anaconda3\envs\pythondata\lib\site-packages (from urllib3[secure,socks]~=1.26->selenium) (2021.10.8)
# Requirement already satisfied: six>=1.5.2 in c:\users\rashi\anaconda3\envs\pythondata\lib\site-packages (from pyOpenSSL>=0.14->urllib3[secure,socks]~=1.26->selenium) (1.16.0)
# Requirement already satisfied: h11<1,>=0.9.0 in c:\users\rashi\anaconda3\envs\pythondata\lib\site-packages (from wsproto>=0.14->trio-websocket~=0.9->selenium) (0.13.0)
# Requirement already satisfied: typing-extensions in c:\users\rashi\anaconda3\envs\pythondata\lib\site-packages (from h11<1,>=0.9.0->wsproto>=0.14->trio-websocket~=0.9->selenium) (3.10.0.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
# Set up your executable path then set up URL for scraping 
executable_path = {'executable_path': ChromeDriverManager().install()}
browser = Browser('chrome', **executable_path, headless=False)
# Out:
# [WDM] - ====== WebDriver manager ======
# [WDM] - Current google-chrome version is 103.0.5060
# [WDM] - Get LATEST chromedriver version for 103.0.5060 google-chrome
# [WDM] - About to download new driver from https://chromedriver.storage.googleapis.com/103.0.5060.53/chromedriver_win32.zip
# [WDM] - Driver has been saved in cache [C:\Users\rashi\.wdm\drivers\chromedriver\win32\103.0.5060.53]

# %%
# Visit the mars nasa news site
url = 'https://redplanetscience.com'
browser.visit(url)
# Optional delay for loading the page
browser.is_element_present_by_css('div.list_text', wait_time=1)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_8868/3354026284.py in <module>
#       3 browser.visit(url)
#       4 # Optional delay for loading the page
# ----> 5 browser.is_element_present_by_css('div.list_text', wait_time=1)
#
# ~\anaconda3\envs\PythonData\lib\site-packages\splinter\driver\webdriver\__init__.py in is_element_present_by_css(self, css_selector, wait_time)
#     379
#     380     def is_element_present_by_css(self, css_selector, wait_time=None):
# --> 381         return self.is_element_present(self.find_by_css, css_selector, wait_time)
#     382
#     383     def is_element_not_present_by_css(self, css_selector, wait_time=None):
#
# ~\anaconda3\envs\PythonData\lib\site-packages\splinter\driver\webdriver\__init__.py in is_element_present(self, finder, selector, wait_time)
#     365
#     366         while time.time() < end_time:
# --> 367             if finder(selector, wait_time=wait_time):
#     368                 return True
#     369         return False
#
# ~\anaconda3\envs\PythonData\lib\site-packages\splinter\driver\webdriver\__init__.py in find_by_css(self, css_selector, wait_time)
#     532     def find_by_css(self, css_selector, wait_time=None):
#     533         return self.find_by(
# --> 534             self.driver.find_elements_by_css_selector,
#     535             css_selector,
#     536             original_find="css",
#
# AttributeError: 'WebDriver' object has no attribute 'find_elements_by_css_selector'

# %%
# Set up HTML parser
html = browser.html
news_soup = soup(html, 'html.parser')
slide_elem = news_soup.select_one('div.list_text')

# %%
# The data we're looking for is the content title, which we've specified by saying, "The specific data is in a <div /> with a class of 'content_title'."
slide_elem.find('div', class_='content_title')
# Out:
# <div class="content_title">NASA's MAVEN Maps Winds in the Martian Upper Atmosphere that Mirror the Terrain Below and Gives Clues to Martian Climate</div>

# %%
# Use the parent element to find the first `a` tag and save it as `news_title`
news_title = slide_elem.find('div', class_='content_title').get_text()
news_title
# Out:
# "NASA's MAVEN Maps Winds in the Martian Upper Atmosphere that Mirror the Terrain Below and Gives Clues to Martian Climate"

# %%
# Use the parent element to find the paragraph text
news_p = slide_elem.find('div', class_='article_teaser_body').get_text()
news_p
# Out:
# 'Researchers have created the first map of wind circulation in the upper atmosphere of a planet besides Earth, using data from NASA’s MAVEN spacecraft that were collected during the last two years.'

# %% [markdown]
# ### Featured Images

# %%
# Visit URL
url = 'https://spaceimages-mars.com'
browser.visit(url)

# %%
# Find and click the full image button
full_image_elem = browser.find_by_tag('button')[1]
full_image_elem.click()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_8868/1716700655.py in <module>
#       1 # Find and click the full image button
# ----> 2 full_image_elem = browser.find_by_tag('button')[1]
#       3 full_image_elem.click()
#
# ~\anaconda3\envs\PythonData\lib\site-packages\splinter\driver\webdriver\__init__.py in find_by_tag(self, tag, wait_time)
#     559     def find_by_tag(self, tag, wait_time=None):
#     560         return self.find_by(
# --> 561             self.driver.find_elements_by_tag_name,
#     562             tag,
#     563             wait_time=wait_time,
#
# AttributeError: 'WebDriver' object has no attribute 'find_elements_by_tag_name'

# %%
# Parse the resulting html with soup
html = browser.html
img_soup = soup(html, 'html.parser')

# %%
# Find the relative image url
img_url_rel = img_soup.find('img', class_='fancybox-image').get('src')
img_url_rel
# Out:
# 'image/featured/mars3.jpg'
